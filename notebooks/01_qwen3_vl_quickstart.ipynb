# %% [markdown]
# # Vision-Language Engineering Lab
#
# **Author:** GHANMI Helmi
# **Current Role:** AI Engineer
# **Past Role:** Researcher in Applied Mathematics
# **Research Profile:** https://www.researchgate.net/profile/Ghanmi-Helmi
#
# This notebook is an analysis/demo client. Reusable implementation lives in `src/vlm_engineering`.

# %% [markdown]
# # Qwen3-VL quickstart
# The notebook only orchestrates `QwenVLModel`; model loading and inference live in the package.

# %%
from vlm_engineering.qwen import QwenVLModel

model = QwenVLModel.from_hub("Qwen/Qwen3-VL-2B-Instruct")

# %%
# print(model.generate("../data/example.jpg", "Describe this image precisely."))
