# %% [markdown]
# # Vision-Language Engineering Lab
#
# **Author:** GHANMI Helmi
# **Current Role:** AI Engineer
# **Past Role:** Researcher in Applied Mathematics
# **Research Profile:** https://www.researchgate.net/profile/Ghanmi-Helmi
#
# This notebook is an analysis/demo client. Reusable implementation lives in `src/vlm_engineering`.

# %% [markdown]
# # CLIP foundations
# Use the production `CLIPEncoder` class for zero-shot classification and text-image similarity.

# %%
from PIL import Image
from vlm_engineering.clip import CLIPEncoder

clip = CLIPEncoder()

# %%
# Add your own image under data/ before running:
# image = Image.open("../data/example.jpg").convert("RGB")
# clip.zero_shot_classify(image, ["cat", "dog", "airplane"])
